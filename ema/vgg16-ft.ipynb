# %%
pip install tensorflow-macos==2.15 tensorflow-metal pandas numpy kaggle seaborn scikit-learn
# Out:
# Requirement already satisfied: tensorflow-macos==2.15 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-metal in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: pandas in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: kaggle in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (1.6.17)
# Requirement already satisfied: seaborn in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (3.4.0)
# Requirement already satisfied: packaging in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (4.25.5)
# Requirement already satisfied: setuptools in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.67.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.0)
# Requirement already satisfied: wheel~=0.35 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorflow-metal) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: requests in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: webencodings in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import numpy as np
import pandas as pd

import json
import random

import os
from PIL import Image

import tensorflow as tf
from tensorflow import keras as K

import matplotlib.pyplot as plt

# plotting style
plt.style.use("ggplot")

# %%
# Config for DS
DS_PATH = "../ds"
DS_ENTRY = f"{DS_PATH}/Poses.json"

# General config
RANDOM_SEED = 3

# Config for img processing
CHANNELS = 3
IMG_RES = 128
IMG_COUNT_PER_CLASS = 200
VALID_IMG_EXT = [".jpg", ".jpeg", ".png", ".bmp"]

# Config for model training
MAX_N_EPOCHS = 300
INITIAL_LR = 1e-4
BATCH_SIZE = 64

# Config for model callbacks
MODEL_NAME = "vgg16-ft_model.h5"
MONITOR_VALUE = "val_loss"

EARLY_STOPPING_PATIENCE = 10
EARLY_STOPPING_MIN_DELTA = 0.001

# %%
if os.path.exists("./logs"):
    print("[INFO]: Borrando legacy logs")
    os.system("rm -rf ./logs")
    
# %load_ext tensorboard
# Out:
# [INFO]: Borrando legacy logs

# %% [markdown]
# ## Carga del Dataset

# %%
# Download if folder was not present
if not os.path.exists(DS_PATH):
    os.system(
        f"kaggle datasets download -d tr1gg3rtrash/yoga-posture-dataset -p {DS_PATH} --unzip"
    )

with open(DS_ENTRY, "r") as file:
    data = json.load(file)

df = pd.DataFrame(data["Poses"])

df.head()
# Out:
#    id             sanskrit_name english_name  \
# 0   1                  Navasana         Boat
# 1   2            Ardha Navasana    Half-Boat
# 2   3               Dhanurasana          Bow
# 3   4  Setu Bandha Sarvangasana       Bridge
# 4   5           Baddha Konasana    Butterfly
#
#                                              img_url
# 0  https://www.dropbox.com/s/4m64ztxkj8a4dab/boat...
# 1  https://www.dropbox.com/s/1nx0r94msxjwvyp/boat...
# 2  https://www.dropbox.com/s/wizj5kwxvez4c0a/bow....
# 3  https://www.dropbox.com/s/f1w64ybg4sn8ejt/brid...
# 4  https://www.dropbox.com/s/3h2pts6xbn28dh7/butt...

# %%
def resize_and_pad_image(image, img_size):
    # Check for images with transparency and add a white background if needed
    if image.mode in ("RGBA", "LA"):
        # Create a white background image (255, 255, 255 = white)
        white_background = Image.new("RGB", image.size, (255, 255, 255))
        # Paste the RGBA image onto the white background, using the alpha channel as a mask
        white_background.paste(image, (0, 0), mask=image)
        image = white_background  # Update image to have a white background

    original_width, original_height = image.size
    aspect_ratio = original_width / original_height

    # Calculate new dimensions based on aspect ratio
    if original_width > original_height:
        new_width = img_size[0]
        new_height = int(img_size[0] / aspect_ratio)
    else:
        new_height = img_size[1]
        new_width = int(img_size[1] * aspect_ratio)

    # Resize the image with high-quality downsampling
    resized_image = image.resize((new_width, new_height), Image.LANCZOS)

    # Create a new blank image with the target size (white padding)
    padded_image = Image.new("RGB", img_size, (255, 255, 255))

    # Calculate position to paste the resized image onto the padded image
    x_offset = (img_size[0] - resized_image.size[0]) // 2
    y_offset = (img_size[1] - resized_image.size[1]) // 2

    # Paste the resized image onto the padded image
    padded_image.paste(resized_image, (x_offset, y_offset))

    return padded_image

# %%
# import cv2
from pathlib import Path

X = []
y = []
labelNames = {}


print("[INFO]: Leyendo imagenes de poses")
for id, pose in enumerate(df.itertuples()):
    print(f"[INFO]: Procesando pose: {pose.sanskrit_name} / {pose.english_name}")
    labelNames[id] = pose.english_name

    # Obtengo la carpeta de imagenes de la pose
    folder = f"{DS_PATH}/{pose.sanskrit_name}"

    for file in os.listdir(folder):
        img_path = os.path.join(folder, file)

        if Path(img_path).suffix.lower() not in VALID_IMG_EXT:
            print(f"[WARN]: Formato {img_path} no valido")
            continue

        img = Image.open(img_path)

        img = resize_and_pad_image(img, (IMG_RES, IMG_RES))

        X.append(img)
        y.append(id)


# Convertir a numpy array
X = np.array(X)
y = np.array(y)
# Out:
# [INFO]: Leyendo imagenes de poses
# [INFO]: Procesando pose: Navasana / Boat
# [INFO]: Procesando pose: Ardha Navasana / Half-Boat
# [INFO]: Procesando pose: Dhanurasana / Bow
# [INFO]: Procesando pose: Setu Bandha Sarvangasana / Bridge
# [INFO]: Procesando pose: Baddha Konasana / Butterfly
# [INFO]: Procesando pose: Ustrasana / Camel
# [INFO]: Procesando pose: Marjaryasana / Cat
# [INFO]: Procesando pose: Bitilasana / Cow
# [INFO]: Procesando pose: Utkatasana / Chair
# [INFO]: Procesando pose: Balasana / Child's Pose
# /Users/emanuel.suriano/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# [INFO]: Procesando pose: Sivasana / Corpse
# [INFO]: Procesando pose: Alanasana / Crescent Lunge
# [INFO]: Procesando pose: Bakasana / Crow
# [INFO]: Procesando pose: Ardha Pincha Mayurasana / Dolphin
# [INFO]: Procesando pose: Adho Mukha Svanasana / Downward-Facing Dog
# [INFO]: Procesando pose: Garudasana / Eagle
# [INFO]: Procesando pose: Utthita Hasta Padangusthasana / Extended Hand to Toe
# [INFO]: Procesando pose: Utthita Parsvakonasana / Extended Side Angle
# [INFO]: Procesando pose: Pincha Mayurasana / Forearm Stand
# [INFO]: Procesando pose: Uttanasana / Forward Bend with Shoulder Opener
# [INFO]: Procesando pose: Ardha Chandrasana / Half-Moon
# [INFO]: Procesando pose: Adho Mukha Vrksasana / Handstand
# [INFO]: Procesando pose: Anjaneyasana / Low Lunge
# [INFO]: Procesando pose: Supta Kapotasana / Pigeon
# [INFO]: Procesando pose: Eka Pada Rajakapotasana / King Pigeon
# [INFO]: Procesando pose: Phalakasana / Plank
# [INFO]: Procesando pose: Halasana / Plow
# [INFO]: Procesando pose: Parsvottanasana / Pyramid
# [INFO]: Procesando pose: Parsva Virabhadrasana / Reverse Warrior
# [INFO]: Procesando pose: Paschimottanasana / Seated Forward Bend
# [INFO]: Procesando pose: Padmasana / Lotus
# [INFO]: Procesando pose: Ardha Matsyendrasana / Half Lord of the Fishes
# [INFO]: Procesando pose: Salamba Sarvangasana / Shoulder Stand
# [INFO]: Procesando pose: Vasisthasana / Side Plank
# [INFO]: Procesando pose: Salamba Bhujangasana / Sphinx
# [INFO]: Procesando pose: Hanumanasana / Splits
# [INFO]: Procesando pose: Malasana / Squat
# [INFO]: Procesando pose: Uttanasana / Standing Forward Bend
# [INFO]: Procesando pose: Ashta Chandrasana / Crescent Moon
# [INFO]: Procesando pose: Upavistha Konasana / Side Splits
# [INFO]: Procesando pose: Vrksasana / Tree
# [INFO]: Procesando pose: Trikonasana / Triangle
# [INFO]: Procesando pose: Urdhva Mukha Svsnssana / Upward-Facing Dog
# [INFO]: Procesando pose: Virabhadrasana One / Warrior One
# [WARN]: Formato ../ds/Virabhadrasana One/File56.gif no valido
# [INFO]: Procesando pose: Virabhadrasana Two / Warrior Two
# [WARN]: Formato ../ds/Virabhadrasana Two/File56.gif no valido
# [INFO]: Procesando pose: Virabhadrasana Three / Warrior Three
# [INFO]: Procesando pose: Urdhva Dhanurasana / Wheel
# [INFO]: Procesando pose: Camatkarasana / Wild Thing

# %% [markdown]
# ## Sample Preview

# %%
fig = plt.figure(figsize=(16, 14))

samples = np.random.randint(0, len(X), 20)

for i, img_idx in enumerate(samples):
    fig.add_subplot(4, 5, i + 1)

    plt.imshow(X[img_idx])
    plt.title(labelNames[y[img_idx]])
    plt.axis("off")

plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
datagen = K.preprocessing.image.ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2,  # 20% for validation
    # Augmentations (applied only to training subset)
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest",
    brightness_range=(0.8, 1.2),
)

# %%
sample = random.randint(0, len(X))

img_orig = X[sample]

fig = plt.figure(figsize=(16, 10))

fig.add_subplot(4, 8, 1)
plt.imshow(img_orig)
plt.title("Original")
plt.axis("off")

# # Show transformations
for n in range(2, 6):
    fig.add_subplot(4, 8, n)
    img = datagen.random_transform(img_orig)
    plt.imshow(img.astype(np.uint8))
    plt.title(f"Trans {n}")
    plt.axis("off")

plt.show()

# %% [markdown]
# ## Analisis de la distribucion

# %%
y_counts = np.bincount(y)

plt.figure(figsize=(10, 10))
plt.barh(labelNames.values(), y_counts, color="skyblue")
plt.title("Distribucion de poses")
plt.show()

# %% [markdown]
# ## Balanceo de clases - Oversampling

# %%
for label in np.unique(y):
    X_filtered = X[y == label]
    num_augmentations = IMG_COUNT_PER_CLASS - len(X_filtered)

    if num_augmentations > 0:
        print(f"[INFO]: Nuevas {num_augmentations} poses de {labelNames[label]}")
        img_random_order = np.random.permutation(X_filtered)

        X_aug = [
            datagen.random_transform(img_random_order[i % len(X_filtered)]).astype(
                np.uint8
            )
            for i in range(num_augmentations)
        ]

        y_aug = [label] * num_augmentations

        X = np.append(X, np.array(X_aug), axis=0)
        y = np.append(y, np.array(y_aug), axis=0)
# Out:
# [INFO]: Nuevas 182 poses de Boat
# [INFO]: Nuevas 187 poses de Half-Boat
# [INFO]: Nuevas 146 poses de Bow
# [INFO]: Nuevas 134 poses de Bridge
# [INFO]: Nuevas 119 poses de Butterfly
# [INFO]: Nuevas 104 poses de Camel
# [INFO]: Nuevas 144 poses de Cat
# [INFO]: Nuevas 106 poses de Cow
# [INFO]: Nuevas 119 poses de Chair
# [INFO]: Nuevas 121 poses de Child's Pose
# [INFO]: Nuevas 180 poses de Corpse
# [INFO]: Nuevas 182 poses de Crescent Lunge
# [INFO]: Nuevas 116 poses de Crow
# [INFO]: Nuevas 146 poses de Dolphin
# [INFO]: Nuevas 126 poses de Downward-Facing Dog
# [INFO]: Nuevas 115 poses de Eagle
# [INFO]: Nuevas 136 poses de Extended Hand to Toe
# [INFO]: Nuevas 131 poses de Extended Side Angle
# [INFO]: Nuevas 157 poses de Forearm Stand
# [INFO]: Nuevas 129 poses de Forward Bend with Shoulder Opener
# [INFO]: Nuevas 141 poses de Half-Moon
# [INFO]: Nuevas 135 poses de Handstand
# [INFO]: Nuevas 129 poses de Low Lunge
# [INFO]: Nuevas 187 poses de Pigeon
# [INFO]: Nuevas 147 poses de King Pigeon
# [INFO]: Nuevas 134 poses de Plank
# [INFO]: Nuevas 129 poses de Plow
# [INFO]: Nuevas 157 poses de Pyramid
# [INFO]: Nuevas 186 poses de Reverse Warrior
# [INFO]: Nuevas 138 poses de Seated Forward Bend
# [INFO]: Nuevas 123 poses de Lotus
# [INFO]: Nuevas 104 poses de Half Lord of the Fishes
# [INFO]: Nuevas 127 poses de Shoulder Stand
# [INFO]: Nuevas 120 poses de Side Plank
# [INFO]: Nuevas 138 poses de Sphinx
# [INFO]: Nuevas 159 poses de Splits
# [INFO]: Nuevas 127 poses de Squat
# [INFO]: Nuevas 129 poses de Standing Forward Bend
# [INFO]: Nuevas 188 poses de Crescent Moon
# [INFO]: Nuevas 183 poses de Side Splits
# [INFO]: Nuevas 132 poses de Tree
# [INFO]: Nuevas 177 poses de Triangle
# [INFO]: Nuevas 131 poses de Upward-Facing Dog
# [INFO]: Nuevas 137 poses de Warrior One
# [INFO]: Nuevas 140 poses de Warrior Two
# [INFO]: Nuevas 131 poses de Warrior Three
# [INFO]: Nuevas 126 poses de Wheel
# [INFO]: Nuevas 138 poses de Wild Thing

# %%
y_counts = np.bincount(y)

plt.figure(figsize=(10, 10))
plt.barh(labelNames.values(), y_counts, color="skyblue")
plt.title("Distribucion de poses")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=RANDOM_SEED,
    stratify=y,
)

# Output the results
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

# Check the class distribution
print("Class distribution in y_train:", np.bincount(y_train))
print("Class distribution in y_test:", np.bincount(y_test))
# Out:
# X_train: (6720, 128, 128, 3)
# y_train: (6720,)
# X_test: (2880, 128, 128, 3)
# y_test: (2880,)
# Class distribution in y_train: [140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140
#  140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140
#  140 140 140 140 140 140 140 140 140 140 140 140]
# Class distribution in y_test: [60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60
#  60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60]

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import LabelBinarizer

# One hot encoding for labels
lb = LabelBinarizer()
y_train_n = lb.fit_transform(y_train)
y_test_n = lb.transform(y_test)

# %% [markdown]
# ## Model definition - Fine tuning
#
# - VGG16: fine-tune the last block of the model, with 3 Conv layers
# - 1 Hidden layer 128 with BatchNormalization and Dropout

# %%
input_shape = (IMG_RES, IMG_RES, 3)

# Pre-trained
base_model = K.applications.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=input_shape,
)

# Capas para fine-tuning
unfrozen_layer_names = [
    "block5_conv1",
    "block5_conv2",
    "block5_conv3",
]

for layer in base_model.layers:
    layer.trainable = layer.name in unfrozen_layer_names

# Entry layer
model = K.models.Sequential(
    [
        K.layers.Input(shape=input_shape),
        # Add base model
        base_model,
        K.layers.GlobalAveragePooling2D(),
        # Dense layer 1
        K.layers.Dense(128, activation="relu"),
        K.layers.BatchNormalization(),
        K.layers.Dropout(0.3),
        # Output
        K.layers.Dense(len(labelNames), activation="softmax"),
    ]
)


model.compile(
    loss="categorical_crossentropy",
    optimizer=K.optimizers.legacy.Adam(learning_rate=INITIAL_LR),
    metrics=["acc"],
)

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  global_average_pooling2d_1  (None, 512)               0
#  1 (GlobalAveragePooling2D)
#
#  dense_21 (Dense)            (None, 128)               65664
#
#  batch_normalization_11 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 48)                6192
#
# =================================================================
# Total params: 14787056 (56.41 MB)
# Trainable params: 7151536 (27.28 MB)
# Non-trainable params: 7635520 (29.13 MB)
# _________________________________________________________________

# %%
# Use datageneration for training and validation data
train_data = datagen.flow(
    X_train,
    y_train_n,
    batch_size=BATCH_SIZE,
    subset="training",
    seed=RANDOM_SEED,
)

validation_data = datagen.flow(
    X_train,
    y_train_n,
    batch_size=BATCH_SIZE,
    subset="validation",
    seed=RANDOM_SEED,
)

callbacks = [
    #  Integracion con Tensorboard
    K.callbacks.TensorBoard(histogram_freq=1),
    # Early stopping
    K.callbacks.EarlyStopping(
        monitor=MONITOR_VALUE,
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        min_delta=EARLY_STOPPING_MIN_DELTA,
    ),
    # Save the model
    K.callbacks.ModelCheckpoint(
        MODEL_NAME,
        monitor=MONITOR_VALUE,
        save_best_only=True,
        save_weights_only=True,
    ),
]

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=MAX_N_EPOCHS,
    callbacks=callbacks,
)
# Out:
# [INFO]: Entrenando la red...
# Epoch 1/300
# 84/84 [==============================] - 19s 214ms/step - loss: 3.4747 - acc: 0.1520 - val_loss: 3.3429 - val_acc: 0.1399
# Epoch 2/300
# 84/84 [==============================] - 18s 209ms/step - loss: 2.3266 - acc: 0.3847 - val_loss: 2.3056 - val_acc: 0.4152
# Epoch 3/300
#  3/84 [>.............................] - ETA: 13s - loss: 1.8697 - acc: 0.5104
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 39
#      37 # Entrenamiento de la red
#      38 print("[INFO]: Entrenando la red...")
# ---> 39 H = model.fit(
#      40     train_data,
#      41     validation_data=validation_data,
#      42     epochs=MAX_N_EPOCHS,
#      43     callbacks=callbacks,
#      44 )
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Git/deep-learning-group-7/.venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import classification_report

# X_test no tuvo normalizacion
X_test_n = X_test / 255

print("[INFO]: Evaluando el modelo...")
predictions = model.predict(X_test_n, batch_size=BATCH_SIZE)

print(
    classification_report(
        y_test,
        predictions.argmax(axis=1),
        target_names=labelNames.values(),
    )
)
# Out:
# [INFO]: Evaluando el modelo...
# 45/45 [==============================] - 6s 131ms/step
#                                    precision    recall  f1-score   support
#
#                              Boat       1.00      1.00      1.00        60
#                         Half-Boat       1.00      1.00      1.00        60
#                               Bow       0.92      1.00      0.96        60
#                            Bridge       0.97      1.00      0.98        60
#                         Butterfly       0.97      0.95      0.96        60
#                             Camel       0.97      0.98      0.98        60
#                               Cat       0.88      0.88      0.88        60
#                               Cow       0.88      0.88      0.88        60
#                             Chair       0.97      1.00      0.98        60
#                      Child's Pose       0.98      1.00      0.99        60
#                            Corpse       0.98      1.00      0.99        60
#                    Crescent Lunge       0.93      0.87      0.90        60
#                              Crow       0.98      0.88      0.93        60
#                           Dolphin       0.98      1.00      0.99        60
#               Downward-Facing Dog       0.98      0.93      0.96        60
#                             Eagle       1.00      0.95      0.97        60
#              Extended Hand to Toe       0.95      0.95      0.95        60
#               Extended Side Angle       0.89      0.98      0.94        60
#                     Forearm Stand       0.94      0.97      0.95        60
# Forward Bend with Shoulder Opener       0.36      0.45      0.40        60
#                         Half-Moon       1.00      1.00      1.00        60
#                         Handstand       0.93      0.87      0.90        60
#                         Low Lunge       1.00      0.97      0.98        60
#                            Pigeon       0.98      1.00      0.99        60
#                       King Pigeon       1.00      0.95      0.97        60
#                             Plank       0.95      0.98      0.97        60
#                              Plow       0.98      0.98      0.98        60
#                           Pyramid       0.98      1.00      0.99        60
#                   Reverse Warrior       1.00      1.00      1.00        60
#               Seated Forward Bend       1.00      1.00      1.00        60
#                             Lotus       0.98      0.92      0.95        60
#           Half Lord of the Fishes       0.94      0.97      0.95        60
#                    Shoulder Stand       0.95      0.93      0.94        60
#                        Side Plank       0.95      0.90      0.92        60
#                            Sphinx       0.92      0.93      0.93        60
#                            Splits       0.95      1.00      0.98        60
#                             Squat       0.95      0.97      0.96        60
#             Standing Forward Bend       0.31      0.25      0.28        60
#                     Crescent Moon       0.88      0.93      0.90        60
#                       Side Splits       0.98      1.00      0.99        60
#                              Tree       0.98      0.97      0.97        60
#                          Triangle       1.00      0.97      0.98        60
#                 Upward-Facing Dog       0.97      0.93      0.95        60
#                       Warrior One       0.95      1.00      0.98        60
#                       Warrior Two       0.95      1.00      0.98        60
#                     Warrior Three       1.00      0.98      0.99        60
#                             Wheel       1.00      0.88      0.94        60
#                        Wild Thing       0.97      1.00      0.98        60
#
#                          accuracy                           0.94      2880
#                         macro avg       0.94      0.94      0.94      2880
#                      weighted avg       0.94      0.94      0.94      2880

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(H.history)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # 1 row, 2 columns

# Plot 1: Loss and Validation Loss on the first subplot
history_df.loc[:, ["loss", "val_loss"]].plot(ax=axs[0])
axs[0].set_title("Loss")

# Plot 2: Accuracy and Validation Accuracy on the second subplot
history_df.loc[:, ["acc", "val_acc"]].plot(ax=axs[1])
axs[1].set_title("Accuracy")

plt.show()
