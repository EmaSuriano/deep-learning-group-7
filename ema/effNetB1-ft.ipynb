# %%
pip install tensorflow-macos==2.15 tensorflow-metal pandas numpy kaggle seaborn scikit-learn
# Out:
# Requirement already satisfied: tensorflow-macos==2.15 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-metal in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: pandas in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: kaggle in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (1.6.17)
# Requirement already satisfied: seaborn in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (3.4.0)
# Requirement already satisfied: packaging in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (4.25.5)
# Requirement already satisfied: setuptools in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (1.67.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-macos==2.15) (2.15.0)
# Requirement already satisfied: wheel~=0.35 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorflow-metal) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: requests in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: webencodings in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15) (3.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import numpy as np
import pandas as pd

import json
import random

import os
from PIL import Image

import tensorflow as tf
from tensorflow import keras as K

import matplotlib.pyplot as plt

# plotting style
plt.style.use("ggplot")

# %%
# Config for DS
DS_PATH = "../ds"
DS_ENTRY = f"{DS_PATH}/Poses.json"

# General Settings
RANDOM_SEED = 3
TENSORBOARD_ENABLED = True

# Config for img processing
CHANNELS = 3
IMG_RES = 128
IMG_COUNT_PER_CLASS = 200
VALID_IMG_EXT = [".jpg", ".jpeg", ".png", ".bmp"]


# Config for model training
MAX_N_EPOCHS = 300
INITIAL_LR = 1e-3
BATCH_SIZE = 64

# Config for model callbacks
MODEL_NAME = "effNetB1-ft.h5"
MONITOR_VALUE = "val_loss"

EARLY_STOPPING_PATIENCE = 10
EARLY_STOPPING_MIN_DELTA = 0.001

REDUCE_LR_PATIENCE = 5
MIN_LR = 1e-6
REDUCE_LR_FACTOR = 0.1

# %% [markdown]
# ## Carga del Dataset

# %%
# Download if folder was not present
if not os.path.exists(DS_PATH):
    os.system(
        f"kaggle datasets download -d tr1gg3rtrash/yoga-posture-dataset -p {DS_PATH} --unzip"
    )

with open(DS_ENTRY, "r") as file:
    data = json.load(file)

df = pd.DataFrame(data["Poses"])

df.head()
# Out:
#    id             sanskrit_name english_name  \
# 0   1                  Navasana         Boat
# 1   2            Ardha Navasana    Half-Boat
# 2   3               Dhanurasana          Bow
# 3   4  Setu Bandha Sarvangasana       Bridge
# 4   5           Baddha Konasana    Butterfly
#
#                                              img_url
# 0  https://www.dropbox.com/s/4m64ztxkj8a4dab/boat...
# 1  https://www.dropbox.com/s/1nx0r94msxjwvyp/boat...
# 2  https://www.dropbox.com/s/wizj5kwxvez4c0a/bow....
# 3  https://www.dropbox.com/s/f1w64ybg4sn8ejt/brid...
# 4  https://www.dropbox.com/s/3h2pts6xbn28dh7/butt...

# %%
def resize_and_pad_image(image, img_size):
    # Check for images with transparency and add a white background if needed
    if image.mode in ("RGBA", "LA"):
        # Create a white background image (255, 255, 255 = white)
        white_background = Image.new("RGB", image.size, (255, 255, 255))
        # Paste the RGBA image onto the white background, using the alpha channel as a mask
        white_background.paste(image, (0, 0), mask=image)
        image = white_background  # Update image to have a white background

    original_width, original_height = image.size
    aspect_ratio = original_width / original_height

    # Calculate new dimensions based on aspect ratio
    if original_width > original_height:
        new_width = img_size[0]
        new_height = int(img_size[0] / aspect_ratio)
    else:
        new_height = img_size[1]
        new_width = int(img_size[1] * aspect_ratio)

    # Resize the image with high-quality downsampling
    resized_image = image.resize((new_width, new_height), Image.LANCZOS)

    # Create a new blank image with the target size (white padding)
    padded_image = Image.new("RGB", img_size, (255, 255, 255))

    # Calculate position to paste the resized image onto the padded image
    x_offset = (img_size[0] - resized_image.size[0]) // 2
    y_offset = (img_size[1] - resized_image.size[1]) // 2

    # Paste the resized image onto the padded image
    padded_image.paste(resized_image, (x_offset, y_offset))

    return padded_image

# %%
# import cv2
from pathlib import Path

X = []
y = []
labelNames = {}


print("[INFO]: Leyendo imagenes de poses")
for id, pose in enumerate(df.itertuples()):
    print(f"[INFO]: Procesando pose: {pose.sanskrit_name} / {pose.english_name}")
    labelNames[id] = pose.english_name

    # Obtengo la carpeta de imagenes de la pose
    folder = f"{DS_PATH}/{pose.sanskrit_name}"

    for file in os.listdir(folder):
        img_path = os.path.join(folder, file)

        if Path(img_path).suffix.lower() not in VALID_IMG_EXT:
            print(f"[WARN]: Formato {img_path} no valido")
            continue

        img = Image.open(img_path)

        img = resize_and_pad_image(img, (IMG_RES, IMG_RES))

        X.append(img)
        y.append(id)


# Convertir a numpy array
X = np.array(X)
y = np.array(y)
# Out:
# [INFO]: Leyendo imagenes de poses
# [INFO]: Procesando pose: Navasana / Boat
# [INFO]: Procesando pose: Ardha Navasana / Half-Boat
# [INFO]: Procesando pose: Dhanurasana / Bow
# [INFO]: Procesando pose: Setu Bandha Sarvangasana / Bridge
# [INFO]: Procesando pose: Baddha Konasana / Butterfly
# [INFO]: Procesando pose: Ustrasana / Camel
# [INFO]: Procesando pose: Marjaryasana / Cat
# [INFO]: Procesando pose: Bitilasana / Cow
# [INFO]: Procesando pose: Utkatasana / Chair
# [INFO]: Procesando pose: Balasana / Child's Pose
# /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# [INFO]: Procesando pose: Sivasana / Corpse
# [INFO]: Procesando pose: Alanasana / Crescent Lunge
# [INFO]: Procesando pose: Bakasana / Crow
# [INFO]: Procesando pose: Ardha Pincha Mayurasana / Dolphin
# [INFO]: Procesando pose: Adho Mukha Svanasana / Downward-Facing Dog
# [INFO]: Procesando pose: Garudasana / Eagle
# [INFO]: Procesando pose: Utthita Hasta Padangusthasana / Extended Hand to Toe
# [INFO]: Procesando pose: Utthita Parsvakonasana / Extended Side Angle
# [INFO]: Procesando pose: Pincha Mayurasana / Forearm Stand
# [INFO]: Procesando pose: Uttanasana / Forward Bend with Shoulder Opener
# [INFO]: Procesando pose: Ardha Chandrasana / Half-Moon
# [INFO]: Procesando pose: Adho Mukha Vrksasana / Handstand
# [INFO]: Procesando pose: Anjaneyasana / Low Lunge
# [INFO]: Procesando pose: Supta Kapotasana / Pigeon
# [INFO]: Procesando pose: Eka Pada Rajakapotasana / King Pigeon
# [INFO]: Procesando pose: Phalakasana / Plank
# [INFO]: Procesando pose: Halasana / Plow
# [INFO]: Procesando pose: Parsvottanasana / Pyramid
# [INFO]: Procesando pose: Parsva Virabhadrasana / Reverse Warrior
# [INFO]: Procesando pose: Paschimottanasana / Seated Forward Bend
# [INFO]: Procesando pose: Padmasana / Lotus
# [INFO]: Procesando pose: Ardha Matsyendrasana / Half Lord of the Fishes
# [INFO]: Procesando pose: Salamba Sarvangasana / Shoulder Stand
# [INFO]: Procesando pose: Vasisthasana / Side Plank
# [INFO]: Procesando pose: Salamba Bhujangasana / Sphinx
# [INFO]: Procesando pose: Hanumanasana / Splits
# [INFO]: Procesando pose: Malasana / Squat
# [INFO]: Procesando pose: Uttanasana / Standing Forward Bend
# [INFO]: Procesando pose: Ashta Chandrasana / Crescent Moon
# [INFO]: Procesando pose: Upavistha Konasana / Side Splits
# [INFO]: Procesando pose: Vrksasana / Tree
# [INFO]: Procesando pose: Trikonasana / Triangle
# [INFO]: Procesando pose: Urdhva Mukha Svsnssana / Upward-Facing Dog
# [INFO]: Procesando pose: Virabhadrasana One / Warrior One
# [WARN]: Formato ../ds/Virabhadrasana One/File56.gif no valido
# [INFO]: Procesando pose: Virabhadrasana Two / Warrior Two
# [WARN]: Formato ../ds/Virabhadrasana Two/File56.gif no valido
# [INFO]: Procesando pose: Virabhadrasana Three / Warrior Three
# [INFO]: Procesando pose: Urdhva Dhanurasana / Wheel
# [INFO]: Procesando pose: Camatkarasana / Wild Thing

# %% [markdown]
# ## Sample Preview

# %%
fig = plt.figure(figsize=(16, 14))

samples = np.random.randint(0, len(X), 20)

for i, img_idx in enumerate(samples):
    fig.add_subplot(4, 5, i + 1)

    plt.imshow(X[img_idx])
    plt.title(labelNames[y[img_idx]])
    plt.axis("off")

plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
datagen = K.preprocessing.image.ImageDataGenerator(
    preprocessing_function=K.applications.efficientnet.preprocess_input,
    validation_split=0.2,  # 20% for validation
    # Augmentations (applied only to training subset)
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest",
    brightness_range=(0.8, 1.2),
)

# %%
sample = random.randint(0, len(X))

img_orig = X[sample]

fig = plt.figure(figsize=(16, 10))

fig.add_subplot(4, 8, 1)
plt.imshow(img_orig)
plt.title("Original")
plt.axis("off")

# # Show transformations
for n in range(2, 6):
    fig.add_subplot(4, 8, n)
    img = datagen.random_transform(img_orig)
    plt.imshow(img.astype(np.uint8))
    plt.title(f"Trans {n}")
    plt.axis("off")

plt.show()

# %% [markdown]
# ## Analisis de la distribucion

# %%
y_counts = np.bincount(y)

plt.figure(figsize=(10, 10))
plt.barh(labelNames.values(), y_counts, color="skyblue")
plt.title("Distribucion de poses")
plt.show()

# %% [markdown]
# ## Balanceo de clases - Oversampling

# %%
for label in np.unique(y):
    X_filtered = X[y == label]
    num_augmentations = IMG_COUNT_PER_CLASS - len(X_filtered)

    if num_augmentations > 0:
        print(f"[INFO]: Nuevas {num_augmentations} poses de {labelNames[label]}")
        img_random_order = np.random.permutation(X_filtered)

        X_aug = [
            datagen.random_transform(img_random_order[i % len(X_filtered)]).astype(
                np.uint8
            )
            for i in range(num_augmentations)
        ]

        y_aug = [label] * num_augmentations

        X = np.append(X, np.array(X_aug), axis=0)
        y = np.append(y, np.array(y_aug), axis=0)
# Out:
# [INFO]: Nuevas 182 poses de Boat
# [INFO]: Nuevas 187 poses de Half-Boat
# [INFO]: Nuevas 146 poses de Bow
# [INFO]: Nuevas 134 poses de Bridge
# [INFO]: Nuevas 119 poses de Butterfly
# [INFO]: Nuevas 104 poses de Camel
# [INFO]: Nuevas 144 poses de Cat
# [INFO]: Nuevas 106 poses de Cow
# [INFO]: Nuevas 119 poses de Chair
# [INFO]: Nuevas 121 poses de Child's Pose
# [INFO]: Nuevas 180 poses de Corpse
# [INFO]: Nuevas 182 poses de Crescent Lunge
# [INFO]: Nuevas 116 poses de Crow
# [INFO]: Nuevas 146 poses de Dolphin
# [INFO]: Nuevas 126 poses de Downward-Facing Dog
# [INFO]: Nuevas 115 poses de Eagle
# [INFO]: Nuevas 136 poses de Extended Hand to Toe
# [INFO]: Nuevas 131 poses de Extended Side Angle
# [INFO]: Nuevas 157 poses de Forearm Stand
# [INFO]: Nuevas 129 poses de Forward Bend with Shoulder Opener
# [INFO]: Nuevas 141 poses de Half-Moon
# [INFO]: Nuevas 135 poses de Handstand
# [INFO]: Nuevas 129 poses de Low Lunge
# [INFO]: Nuevas 187 poses de Pigeon
# [INFO]: Nuevas 147 poses de King Pigeon
# [INFO]: Nuevas 134 poses de Plank
# [INFO]: Nuevas 129 poses de Plow
# [INFO]: Nuevas 157 poses de Pyramid
# [INFO]: Nuevas 186 poses de Reverse Warrior
# [INFO]: Nuevas 138 poses de Seated Forward Bend
# [INFO]: Nuevas 123 poses de Lotus
# [INFO]: Nuevas 104 poses de Half Lord of the Fishes
# [INFO]: Nuevas 127 poses de Shoulder Stand
# [INFO]: Nuevas 120 poses de Side Plank
# [INFO]: Nuevas 138 poses de Sphinx
# [INFO]: Nuevas 159 poses de Splits
# [INFO]: Nuevas 127 poses de Squat
# [INFO]: Nuevas 129 poses de Standing Forward Bend
# [INFO]: Nuevas 188 poses de Crescent Moon
# [INFO]: Nuevas 183 poses de Side Splits
# [INFO]: Nuevas 132 poses de Tree
# [INFO]: Nuevas 177 poses de Triangle
# [INFO]: Nuevas 131 poses de Upward-Facing Dog
# [INFO]: Nuevas 137 poses de Warrior One
# [INFO]: Nuevas 140 poses de Warrior Two
# [INFO]: Nuevas 131 poses de Warrior Three
# [INFO]: Nuevas 126 poses de Wheel
# [INFO]: Nuevas 138 poses de Wild Thing

# %%
y_counts = np.bincount(y)

plt.figure(figsize=(10, 10))
plt.barh(labelNames.values(), y_counts, color="skyblue")
plt.title("Distribucion de poses")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=RANDOM_SEED,
    stratify=y,
)

# Output the results
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

# Check the class distribution
print("Class distribution in y_train:", np.bincount(y_train))
print("Class distribution in y_test:", np.bincount(y_test))
# Out:
# X_train: (6720, 128, 128, 3)
# y_train: (6720,)
# X_test: (2880, 128, 128, 3)
# y_test: (2880,)
# Class distribution in y_train: [140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140
#  140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140 140
#  140 140 140 140 140 140 140 140 140 140 140 140]
# Class distribution in y_test: [60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60
#  60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60]

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import LabelBinarizer

# One hot encoding for labels
lb = LabelBinarizer()
y_train_n = lb.fit_transform(y_train)
y_test_n = lb.transform(y_test)

# %% [markdown]
# ## Model definition - Fine tuning
#
# - VGG16: fine-tune the last block of the model, with 3 Conv layers
# - 1 Hidden layer 128 with BatchNormalization and Dropout

# %%
input_shape = (IMG_RES, IMG_RES, 3)

# Pre-trained
base_model = K.applications.EfficientNetB1(
    weights="imagenet",
    include_top=False,
    input_shape=input_shape,
)

unfreeze_last_n_layers = 30
for i, layer in enumerate(base_model.layers):
    layer.trainable = i >= len(base_model.layers) - unfreeze_last_n_layers

# Entry layer
model = K.models.Sequential(
    [
        K.layers.Input(shape=input_shape),
        # Add base model
        base_model,
        K.layers.GlobalAveragePooling2D(),
        # Dense layer 1
        K.layers.Dense(128, activation="relu"),
        K.layers.BatchNormalization(),
        K.layers.Dropout(0.3),
        # Output
        K.layers.Dense(len(labelNames), activation="softmax"),
    ]
)


model.compile(
    loss="categorical_crossentropy",
    optimizer=K.optimizers.legacy.Adam(learning_rate=INITIAL_LR),
    metrics=["acc"],
)

model.summary()
# Out:
# 2024-11-08 13:28:14.510027: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-11-08 13:28:14.510079: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-11-08 13:28:14.510099: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-11-08 13:28:14.510176: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-08 13:28:14.510205: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb1 (Functional  (None, 4, 4, 1280)        6575239
#  )
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 48)                6192
#
# =================================================================
# Total params: 6745911 (25.73 MB)
# Trainable params: 2642224 (10.08 MB)
# Non-trainable params: 4103687 (15.65 MB)
# _________________________________________________________________

# %%
# Use datageneration for training and validation data
train_data = datagen.flow(
    X_train,
    y_train_n,
    batch_size=BATCH_SIZE,
    subset="training",
    seed=RANDOM_SEED,
)

validation_data = datagen.flow(
    X_train,
    y_train_n,
    batch_size=BATCH_SIZE,
    subset="validation",
    seed=RANDOM_SEED,
)

callbacks = [
    # Early stopping
    K.callbacks.EarlyStopping(
        monitor=MONITOR_VALUE,
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        min_delta=EARLY_STOPPING_MIN_DELTA,
    ),
    # Reduce LR
    K.callbacks.ReduceLROnPlateau(
        monitor=MONITOR_VALUE,
        factor=REDUCE_LR_FACTOR,
        patience=REDUCE_LR_PATIENCE,
        min_lr=MIN_LR,
    ),
    # Save the model
    K.callbacks.ModelCheckpoint(
        MODEL_NAME,
        monitor=MONITOR_VALUE,
        save_best_only=True,
        save_weights_only=True,
    ),
]

if TENSORBOARD_ENABLED:
    callbacks.append(
        K.callbacks.TensorBoard(histogram_freq=1),
    )
    if os.path.exists("./logs"):
        print("[INFO]: Borrando legacy logs")
        os.system("rm -rf ./logs")

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H = model.fit(
    train_data,
    validation_data=validation_data,
    epochs
# Epoch 34/300
# 84/84 [==============================] - 76s 906ms/step - loss: 0.1387 - acc: 0.9520 - val_loss: 0.3022 - val_acc: 0.9062 - lr: 1.0000e-04
# Epoch 35/300
# 84/84 [==============================] - 181s 2s/step - loss: 0.1381 - acc: 0.9526 - val_loss: 0.2937 - val_acc: 0.9159 - lr: 1.0000e-04
# Epoch 36/300
# 84/84 [==============================] - 146s 2s/step - loss: 0.1286 - acc: 0.9563 - val_loss: 0.3044 - val_acc: 0.9085 - lr: 1.0000e-04
# Epoch 37/300
# 84/84 [==============================] - 70s 832ms/step - loss: 0.1294 - acc: 0.9537 - val_loss: 0.2743 - val_acc: 0.9234 - lr: 1.0000e-04
# Epoch 38/300
# 84/84 [==============================] - 58s 689ms/step - loss: 0.1239 - acc: 0.9568 - val_loss: 0.2842 - val_acc: 0.9182 - lr: 1.0000e-04
# Epoch 39/300
# 84/84 [==============================] - 49s 575ms/step - loss: 0.1259 - acc: 0.9559 - val_loss: 0.3046 - val_acc: 0.9137 - lr: 1.0000e-04
# Epoch 40/300
# 84/84 [==============================] - 57s 674ms/step - loss: 0.1188 - acc: 0.9593 - val_loss: 0.2849 - val_acc: 0.9122 - lr: 1.0000e-04
# Epoch 41/300
# 84/84 [==============================] - 57s 673ms/step - loss: 0.1228 - acc: 0.9565 - val_loss: 0.2880 - val_acc: 0.9152 - lr: 1.0000e-04
# Epoch 42/300
# 84/84 [==============================] - 98s 1s/step - loss: 0.1153 - acc: 0.9594 - val_loss: 0.2874 - val_acc: 0.9100 - lr: 1.0000e-04
# Epoch 43/300
# 84/84 [==============================] - 148s 2s/step - loss: 0.1036 - acc: 0.9621 - val_loss: 0.2785 - val_acc: 0.9144 - lr: 1.0000e-05
# Epoch 44/300
# 84/84 [==============================] - 143s 2s/step - loss: 0.1138 - acc: 0.9589 - val_loss: 0.2940 - val_acc: 0.9092 - lr: 1.0000e-05
# Epoch 45/300
# 84/84 [==============================] - 71s 841ms/step - loss: 0.1117 - acc: 0.9621 - val_loss: 0.2994 - val_acc: 0.9092 - lr: 1.0000e-05
# Epoch 46/300
# 84/84 [==============================] - 46s 543ms/step - loss: 0.1175 - acc: 0.9581 - val_loss: 0.3013 - val_acc: 0.9100 - lr: 1.0000e-05
# Epoch 47/300
# 84/84 [==============================] - 55s 642ms/step - loss: 0.1186 - acc: 0.9602 - val_loss: 0.2841 - val_acc: 0.9196 - lr: 1.0000e-05

# %%
from sklearn.metrics import classification_report

# X_test no tuvo normalizacion
X_test_n = K.applications.efficientnet.preprocess_input(X_test)

print("[INFO]: Evaluando el modelo...")
predictions = model.predict(X_test_n, batch_size=BATCH_SIZE)

print(
    classification_report(
        y_test,
        predictions.argmax(axis=1),
        target_names=labelNames.values(),
    )
)
# Out:
# [INFO]: Evaluando el modelo...
# 45/45 [==============================] - 5s 117ms/step
#                                    precision    recall  f1-score   support
#
#                              Boat       0.98      1.00      0.99        60
#                         Half-Boat       0.98      1.00      0.99        60
#                               Bow       0.98      0.97      0.97        60
#                            Bridge       0.94      0.97      0.95        60
#                         Butterfly       0.92      0.93      0.93        60
#                             Camel       0.98      0.93      0.96        60
#                               Cat       0.92      0.90      0.91        60
#                               Cow       0.89      0.92      0.90        60
#                             Chair       1.00      0.98      0.99        60
#                      Child's Pose       0.98      0.97      0.97        60
#                            Corpse       1.00      1.00      1.00        60
#                    Crescent Lunge       0.86      0.80      0.83        60
#                              Crow       0.96      0.92      0.94        60
#                           Dolphin       0.91      1.00      0.95        60
#               Downward-Facing Dog       0.96      0.88      0.92        60
#                             Eagle       0.97      0.98      0.98        60
#              Extended Hand to Toe       0.98      0.97      0.97        60
#               Extended Side Angle       0.97      0.95      0.96        60
#                     Forearm Stand       0.92      0.98      0.95        60
# Forward Bend with Shoulder Opener       0.40      0.45      0.42        60
#                         Half-Moon       1.00      0.97      0.98        60
#                         Handstand       0.96      0.92      0.94        60
#                         Low Lunge       0.98      0.88      0.93        60
#                            Pigeon       1.00      1.00      1.00        60
#                       King Pigeon       0.92      0.98      0.95        60
#                             Plank       0.85      0.97      0.91        60
#                              Plow       1.00      0.90      0.95        60
#                           Pyramid       0.95      1.00      0.98        60
#                   Reverse Warrior       0.95      1.00      0.98        60
#               Seated Forward Bend       0.94      0.97      0.95        60
#                             Lotus       0.90      0.95      0.93        60
#           Half Lord of the Fishes       0.96      0.92      0.94        60
#                    Shoulder Stand       0.97      0.98      0.98        60
#                        Side Plank       0.91      0.82      0.86        60
#                            Sphinx       0.98      0.93      0.96        60
#                            Splits       0.95      1.00      0.98        60
#                             Squat       0.98      0.88      0.93        60
#             Standing Forward Bend       0.37      0.32      0.34        60
#                     Crescent Moon       0.81      0.92      0.86        60
#                       Side Splits       1.00      1.00      1.00        60
#                              Tree       0.98      0.95      0.97        60
#                          Triangle       1.00      1.00      1.00        60
#                 Upward-Facing Dog       0.85      0.93      0.89        60
#                       Warrior One       0.95      0.90      0.92        60
#                       Warrior Two       0.95      1.00      0.98        60
#                     Warrior Three       0.97      0.93      0.95        60
#                             Wheel       0.95      0.93      0.94        60
#                        Wild Thing       0.92      0.95      0.93        60
#
#                          accuracy                           0.93      2880
#                         macro avg       0.93      0.92      0.92      2880
#                      weighted avg       0.93      0.93      0.92      2880

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(H.history)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # 1 row, 2 columns

# Plot 1: Loss and Validation Loss on the first subplot
history_df.loc[:, ["loss", "val_loss"]].plot(ax=axs[0])
axs[0].set_title("Loss")

# Plot 2: Accuracy and Validation Accuracy on the second subplot
history_df.loc[:, ["acc", "val_acc"]].plot(ax=axs[1])
axs[1].set_title("Accuracy")

plt.show()

# %%
# Save the model to be loaded later
model.save(MODEL_NAME)
# Out:
# /Users/emanuel.suriano/Git/deep-learning-group-7/env/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
